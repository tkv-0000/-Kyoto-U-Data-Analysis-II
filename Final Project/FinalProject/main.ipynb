# %% [markdown]
# ___
#
# # Payment method in E-commerce: Analysis of psychological factors affecting the use of Buy Now - Pay Later
#
#
# ### Overview:
#
# * **Name**:  To Khanh Van
# * **Student number**:  B990379551
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The main purpose of the Final project is to analyze factors influencing impulsive online buying behavior among users and non-users of e-Paylater services
# * The key **dependent variable** (DV) of the dataset is Impulsive Buying Behavior (IBB). e-Paylater User Status (Status) would also be considered a supplementary **dependent variable** in predictive analysis.
# * The 5 **independent variables** (IVs) of the dataset are:
#     - Promotion
#     - Social Influence
#     - Happiness
#     - Self-Control
#     - Normative Evaluation
# * The 3 **control variables** (CVs) of the dataset are:
#     - Gender
#     - Monthly Income
#     - User Status
# * The dataset has 811 cases from 811 unique respondants. All accurate DVs and IVs are present in all rows.
# <br>

# %% [markdown]
# ### Dataset source:
#
# - The dataset gathers responses from online impulsive buying behavior of buy now pay later users and non-buy now pay later users in Indonesia and available in [ScienceDirect](https://www.sciencedirect.com/).
#
# - The direct link for the dataset is available for download [here](https://data.mendeley.com/datasets/wkjdmrmrg4/4)
#
# - The dataset originates from an article publised by Verni Juita, Vera Pujani, Rida Rahim, Rita Rahayu (2024)
#
#
#
# **References:**
#
# Juita, V., Pujani, V., Rahim, R., & Rahayu, R. (2024). Dataset on online impulsive buying behavior of buy now pay later users and non-buy now pay later users in Indonesia using the stimulus-organism-response model. Data in Brief, 54, Article 110500. https://doi.org/10.1016/j.dib.2024.110500

# %% [markdown]
# ---

# %% [markdown]
# ## Descriptive Statistics

# %%
# %%capture
# %run descriptive.ipynb

# %%
display_central_tendency_std_table(num=1)
box_plot(num = 1)
# Out:
# <br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary and standard deviation.</span></p>
#          Status      P     SC     SI     NE      H    IBB
# mean      0.252  2.328  2.949  2.351  3.427  3.501  2.752
# median    0.000  2.000  3.000  2.167  3.400  3.750  2.750
# mode      0.000  1.000  3.000  2.000  3.000  4.000  2.000
# st.dev.   0.434  1.116  0.858  0.989  0.886  0.828  0.879
# <br><p><span style="font-size: 1.2em;"><b>Figure 1</b>: Box plot for distribution visualization of variables</span></p>

# %% [markdown]
# From tables and figures above, we can see that all psychological factors shows different central tendencies and variance:
# - Most of the respondents are non-user (nearly 80%).
# - Promotion, Social Influence is right-skewed, showing that most respondents shows low to medium influence by these psychological aspects. Promotion also shows the highest variance among all factors, meaning they are heterogeneous across respondents
# - Self-Control and Impulsive Buying Behavior are fairly bell-shaped and symmetrical. These factors have moderate effects on most respondents.
# - Normative Evaluation and Happiness are left-skewed, with outliers witnessed in Happiness score. Respondents generally shows high content in online shopping, but also shows high morality in shopping impulsively.
#
# With such diverse effects, these analysis supports the use of multivariate models in following sections.

# %%
plot_descriptive(num = 2)
# Out:
# <br><p><span style="font-size: 1.2em;"><b>Figure 2</b>: Correlations amongst main variables.</span></p>

# %% [markdown]
# The correlation between independent variables and Impulsive Buying Behavior ranges from low to moderate correlation, strongly suggesting the use of multivariate model to analyze the effect of the IVs to the DV.
#
# Social Influence, Promotion, and Happiness show moderate positive correlation, while Self-Control is negatively correlated with Impulsive Buying Behavior. The patterns align with existing theoretical expectations and public perspectives on consumer behavior.
#
# Normative Evaluation has low negative correlation score, which signal little influence on Impulsive Buying Behavior.

# %% [markdown]
# ---

# %% [markdown]
# ## Classical Hypothesis Testing

# %%
# %%capture
# %run classical.ipynb

# %%
difference_table()
# Out:
# <br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Welch's ANOVA test for IBB mean score throughout Promotion categories (Low, Medium, High)</span></p>
#       Source  ddof1     ddof2        F  p-unc     np2
# 0  P_Segment      2  353.2252  50.7753    0.0  0.1047
# <br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Games-Howell Post Hoc Results for segmented Promotion respondents</span></p>
#       A       B  mean(A)  mean(B)  Difference    se     T      df  pval  \
# 0  High     Low     3.26     2.53        0.73  0.07  9.89  281.90   0.0
# 1  High  Medium     3.26     2.88        0.38  0.09  4.44  329.18   0.0
# 2   Low  Medium     2.53     2.88       -0.35  0.07 -4.90  371.29   0.0
#
#    hedges
# 0    0.87
# 1    0.48
# 2   -0.41

# %% [markdown]
# P-value  $\alpha$ < 0.05, so we reject the null hypothesis of the means of all groups are equal
#
# We can see that segmenting respondents based on Promotion witnessing the difference in Impulsive Buying Behavior score comes from the High and Low Promotion respondents, which is totally expected.
#
# However, the second highest difference comes from the High and Medium respondents, proving that segmenting respondents between these categories yield positive results. This information is crucial to BNPL services in further segmenting their customer base or potential customers.

# %%
ols_hypothesis()
# Out:
# <br><p><span style="font-size: 1.2em;"><b>Table 3</b>: Hypothesis testing for associations with Impulsive Buying Behaviour - no demographic variables</span></p>
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# P              0.0417      0.038      1.100      0.272      -0.033       0.116
# SI             0.3790      0.042      8.990      0.000       0.296       0.462
# H              0.4103      0.029     14.220      0.000       0.354       0.467
# SC            -0.0167      0.027     -0.613      0.540      -0.070       0.037
# NE             0.0990      0.028      3.582      0.000       0.045       0.153
# ...
# <br><p><span style="font-size: 1.2em;"><b>Table 4</b>: Hypothesis testing for associations with Impulsive Buying Behaviour - with demographic variables</span></p>
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# Social Influence and Happiness is statistically significant and we can imply **positive** causation effects on Impulsive Buying Behavior.
#
# Self-Control and Normative Evaluation is statistically significant and we can imply **negative** causation effects on Impulsive Buying Behaviour respectively.
#
# Promotion is not statistically significant after adding demographic variables into the model, so we cannot make any conclusion on its effects on Impulsive Buying Behaviour
#
# Income, Gender, and Status are statistically significant in predicting IBB score, making them valid control variables.

# %% [markdown]
# ---

# %% [markdown]
# ## Machine Learning

# %%
# %%capture
# %run improved.ipynb

# %%
L1_LG_results()
# Out:
# <br><p><span style="font-size: 1.2em;"><b>Figure 1</b>: Logistic Regression model's performance in predicting User Status</span></p>

# %% [markdown]
# While Impulsive Buying Behavior (IBB) tells how much a customer is willing to spend their money on the service, we would also need to correctly assess our true customer base that are using or has used our services.
#
# The Logistic Regression model helps us to leverage information on the psychological aspects to determine the User Status, from which we get a general picture of our customers and aids in future directions of our service. This serves as a complementary tool to seperate user and non-user, supporting the role of User Status as potential control variables in future analysis on Impulsive Buying Behavior.
#
# The model benefits from a high recall accuracy, which resembles closer with the business's customer base. Missing a false negative user respondent is much more costly for business than identify a false positive non-user.
#
# The top feature with the most influential effect on the model's decision-making are Promotion, Social Influence, and Happiness.

# %% [markdown]
# ---

# %% [markdown]
# ## Summary

# %% [markdown]
# With thorough investigations into the dataset regarding online impulsive buying behavior triggered by the e-Paylater payment alternative, let's summarize our key findings!

# %% [markdown]
# ### Descriptive and Exploratory Data Analysis

# %% [markdown]
# - Impulsive Buying Behaviour: Has right-skewed distribution, showing a notable portion of respondents have low to moderate IBB. Business can influence higher spending through stimulating an increase in IBB score.
# - Happiness and Normative Evaluation has higher central tendency, indicates positive emotional states but also high morality while using online shopping. Promotion and Social Influence shows greater dispersion, showing diversity in respondents' answers.
# - Social Influence and Happiness are moderately and positively associated, while Self-Control is negatively associated with Impulsive Buying Behavior.
# - Promotion is a notable positive correlation between Promotion and Impulsive Buying Behavior and display differences across different Promotion category, but we cannot determine whether Promotion has causation relationship.
# Individual bivariate correlations with IBB are modest, suggesting no single dominant predictor.

# %% [markdown]
# ### Machine Learning for Predictive Analysis

# %% [markdown]
# - Logistic Regression model demonstrates that psychological factors can distinguish between users and non-users.
# - Multiple notable contributors to the model supports the use of multivariate model to interpret and predict Impulsive Buying Behavior

# %% [markdown]
# ### Suggestions to Business

# %% [markdown]
# - Leverage the effect of Promotion: segment and target people with high impulsivity
# - Building the business's image as a reliable and responsible providers, both financially and credibly (Social Influence and Self-Control related)
# - Design marketing campaigns that associate with positive emotional states
